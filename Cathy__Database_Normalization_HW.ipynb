# %% [markdown]
# <a href="https://colab.research.google.com/github/cathymonkey/Unit_3/blob/main/Cathy__Database_Normalization_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Scenario
#
# Conside the following data from a school:
#
# | Student Name  | Fees Paid | Date of Birth | Address                             | Subject 1              | Subject 2                 | Subject 3          | Subject 4 | Teacher Name   | Teacher Address               | Course Name      |
# |---------------|-----------|---------------|-------------------------------------|------------------------|---------------------------|--------------------|-----------|----------------|-------------------------------|------------------|
# | John Smith    | 18-Jul-00 | 04-Aug-91     | 3 Main Street, North Boston 56125   | Economics 1 (Business) | Biology 1 (Science)       |                    |           | James Peterson | 44 March Way, Glebe 56100     | Economics        |
# | Maria Griffin | 14-May-01 | 10-Sep-92     | 16 Leeds Road, South Boston 56128   | Biology 1 (Science)    | Business Intro (Business) | Programming 2 (IT) |           | James Peterson | 44 March Way, Glebe 56100     | Computer Science |
# | Susan Johnson | 03-Feb-01 | 13-Jan-91     | 21 Arrow Street, South Boston 56128 | Biology 2 (Science)    |                           |                    |           | Sarah Francis  |                               | Medicine         |
# | Matt Long     | 29-Apr-02 | 25-Apr-92     | 14 Milk Lane,Â South Boston 56128   |                        |                           |                    |           | Shane Cobson   | 105 Mist Road, Faulkner 56410 | Dentistry        |
#
#
#
# 1. Normalize this table up to **3NF** [(see slides from class here)](https://https://docs.google.com/presentation/d/1sADUiD8YFt88YvV8UyHVhhPe7ks8K8Xpp3y-WPDJ2zc/edit#slide=id.p)
#
# **Table : Students**
#
# | student_id |      name     | fees paid | date of birth |              student address               |       subject 1       |         subject 2        |     subject 3     | subject 4 |
# |:----------:|:-------------:|:---------:|:-------------:|:-----------------------------------:|:---------------------:|:------------------------:|:-----------------:|:---------:|
# |      1     |   John Smith  | 18-Jul-00 |   04-Aug-91   |  3 Main Street, North Boston 56125  | Economics 1(Business) |    Biology 1 (Science)   |        None       |    None   |
# |      2     | Maria Griffin | 14-May-01 |   10-Sep-92   |  16 Leeds Road, South Boston 56128  |    Biology(Science)   | Business Intro(Business) | Programming 2(IT) |    None   |
# |      3     | Susan Johnson | 03-Feb-01 |   13-Jan-91   | 21 Arrow Street, South Boston 56128 |   Biology 2(Science)  |           None           |        None       |    None   |
# |      4     |   Matt Long   | 29-Apr-02 |   25-Apr-92   |  14 Milk Lane,Â South Boston 56128  |          None         |           None           |        None       |    None   |
#
#
# **Table: Teachers**
#
# | teacher_id |      name      |        teacher address        |
# |:----------:|:--------------:|:-----------------------------:|
# |      1     | James Peterson |   44 March Way, Glebe 56100   |
# |      2     |  Sarah Francis |              None             |
# |      3     |  Shane Cobson  | 105 Mist Road, Faulkner 56410 |
#
#
# **Table: Subjects**
#
# | id 	| subject        	|
# |:--:	|----------------	|
# |  1 	|    Biology 1   	|
# | 2  	|    Biology 2   	|
# |  3 	| Business Intro 	|
# |  4 	|   Economics 1  	|
# | 5  	| Programming 2  	|
#
# **Table: Students & Subjects**
#
# | id 	| student_id 	| subject_id 	|
# |:--:	|:----------:	|:----------:	|
# |  1 	|      1     	|      1     	|
# |  2 	|      1     	|      4     	|
# |  3 	|      2     	|      1     	|
# |  4 	|      2     	|      3     	|
# |  5 	|      2     	|      5     	|
# |  6 	|      3     	|      2     	|
# |  7 	|      4     	|            	|
#
# **Table: Teachers & courses**
#
# | id 	| teacher_id 	| course           	|
# |:--:	|------------	|------------------	|
# |  1 	|      1     	| Economics        	|
# | 2  	|      1     	| Computer Science 	|
# |  3 	|      2     	|     Medicine     	|
# |  4 	|      3     	|     Dentistry    	|
#
#
# **Table: Teachers & Subjects**
#
# | id 	| teacher_id 	| subject_id 	|
# |:--:	|:----------:	|:----------:	|
# |  1 	|      1     	|      3     	|
# |  2 	|      1     	|      4     	|
# |  3 	|      2     	|      1     	|
# |  4 	|      2     	|      2     	|
# |  5 	|      3     	|      5     	|
#
#
#
# 2. Create the ER diagram for the normalized database.

# %% [markdown]
# ###**ER Diagram**###
#
# ![Screen Shot 2021-02-18 at 22.55.36.png](data:image/png;base64,...)

# %% [markdown]
# ##[HL]
# 1. Research the SQl commands that are required for the operations CREATE, SELECT,and INSERT.
#
# ### **SQL Commands**

# %%
CREATE TABLE table_name (
    column1 datatype,
    column2 datatype,
    column3 datatype,
   ....
);## Create a table

SELECT * FROM table_name; ## To select data from the table

SELECT DISTINCT column1, column2, ...
FROM table_name; ## To select distinct data from the table

INSERT INTO table_name ## usually no need to write this : (column1, column2, column3, ...)
VALUES (value1, value2, value3, ...); ## To insert values into the table and must be in the same order as of the table's column.

# %% [markdown]
# ##Study Material
# [1] Short tutorial and easy read about Normalization [Guru99](https://www.guru99.com/database-normalization.html)
#
# [2] Short video tutorial on SQL by [Danielle The](https://www.youtube.com/watch?v=27axs9dO7AE)
